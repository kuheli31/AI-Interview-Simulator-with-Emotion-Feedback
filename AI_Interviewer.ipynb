# %% [markdown]
# <a href="https://colab.research.google.com/github/kuheli31/AI-Interview-Simulator-with-Emotion-Feedback/blob/main/AI_Interviewer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai-whisper deepface opencv-python moviepy google-generativeai
